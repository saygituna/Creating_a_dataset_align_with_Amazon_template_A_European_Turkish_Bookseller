# %%
import pandas as pd
import re
#import dataset 
df = pd.read_excel("...your path...sample_dataset.xlsx", 
                   usecols=('Id', 'Stok Kodu', 'Ürün Adı', 'Fiyat', 
                   'Satışta', 'Yazar', 'Yayınevi', 'Resim', 'Açıklama','Sayfa Sayısı', 'Basım Tarihi', 'Dili'))

#Prices are corrected (Previous Sales Strategy was equal to 33% of Turkish Lira Prices)
df["Fiyat"] = df["Fiyat"]/33*100

#If the page number of a book is missing that book is considered 500 aligning with the company owner's decision
df.loc[df["Sayfa Sayısı"] == 0, "Sayfa Sayısı"] = 500

#repricing strategy
#the current currency is selected at 2.5.2023. Price per page, mark-up, and shipping cost are added followingly
df["Fiyat"] = df["Fiyat"]/21.50+ df["Sayfa Sayısı"]*0.01+5+3

#Amazon collects a profit of 15% and 1 euro for each product. 8% VAT is also calculated. The final formula is below
df["standard_price"] = (df["Fiyat"]*100+100)/77

#the columns that are no longer needed are dropped
df = df.drop(columns=["Fiyat"])
df = df.drop(columns=["Satışta"])

#Languages are renamed based on Amazon template
df["Dili"] = df["Dili"].replace({r"\s-\s\w+"}, {""}, regex=True)
df["Dili"].fillna("Nicht qualifiziert", inplace = True)
df.loc[df["Dili"] == "Türkçe", "Dili"] = "Turkish"
df.loc[df["Dili"] == "Osmanlıca", "Dili"] = "Ottoman Turkish"
df.loc[df["Dili"] == "İngilizce", "Dili"] = "Englisch"
df.loc[df["Dili"] == "Fransızca", "Dili"] = "Französisch"
df.loc[df["Dili"] == "Almanca", "Dili"] = "Deutsch"
df.loc[df["Dili"] == "Arapça", "Dili"] = "Arabic"
df.loc[df["Dili"] == "Rusça", "Dili"] = "Russian"
df.loc[df["Dili"] == "Osmanlı Türkçesi", "Dili"] = "Turkish"
df.loc[df["Dili"] == "Farsça", "Dili"] = "Farsi"
df.loc[df["Dili"] == "Latince", "Dili"] = "Latin"
df.loc[df["Dili"] == "İspanyolca", "Dili"] = "Turkish"
df.loc[df["Dili"] == "Ermenice", "Dili"] = "Armenian"
df.loc[df["Dili"] == "Kürtçe", "Dili"] = "Kurdish"
df.loc[df["Dili"] == "Hollandaca", "Dili"] = "Niederländisch"
df.loc[df["Dili"] == "İtalyanca", "Dili"] = "Italienisch"
df.loc[df["Dili"] == "Japonca", "Dili"] = "Turkish"
df.loc[df["Dili"] == "Arnavutça", "Dili"] = "Albanian"
df.loc[df["Dili"] == "Çince", "Dili"] = "Chinese"
df.loc[df["Dili"] == "Yunanca", "Dili"] = "Griechisch"
df.loc[df["Dili"] == "Uygurca", "Dili"] = "Uighur"
df.loc[df["Dili"] == "Abazaca", "Dili"] = "Turkish"
df.loc[df["Dili"] == "Endozenyaca", "Dili"] = "Indonesian"
df.loc[df["Dili"] == "Portekizce", "Dili"] = "Portugiesisch"
df.loc[df["Dili"] == "Kurmanci", "Dili"] = "Kurdish"
df.loc[df["Dili"] == "Norveççe", "Dili"] = "Norwegian"
df.loc[df["Dili"] == "Zazaca", "Dili"] = "Zaza"
df.loc[df["Dili"] == "Tacikçe", "Dili"] = "Tajik"
df.loc[df["Dili"] == "Romence", "Dili"] = "Rumänisch"
df.loc[df["Dili"] == "Polonyaca", "Dili"] = "Polnisch"
df.loc[df["Dili"] == "Tatarca", "Dili"] = "Tatar"
df.loc[df["Dili"] == "İsveççe", "Dili"] = "Schwedisch"
df.loc[df["Dili"] == "Bulgarca", "Dili"] = "Bulgarisch"
df.loc[df["Dili"] == "Boşnakça", "Dili"] = "Bosnier"
df.loc[df["Dili"] == "Özbek Türkçesi", "Dili"] = "Uzbek"
df.loc[df["Dili"] == "Kazak Türkçesi", "Dili"] = "Turkish"
df.loc[df["Dili"] == "Kırgız Türkçesi", "Dili"] = "Kirghiz"
df.loc[df["Dili"] == "Türkmence", "Dili"] = "Turkmen"
df.loc[df["Dili"] == "Urduca", "Dili"] = "Urdu"
df.loc[df["Dili"] == "Makedonca", "Dili"] = "Macedonian"
df.loc[df["Dili"] == "Maltaca", "Dili"] = "Maltese"
df.loc[df["Dili"] == "Korece", "Dili"] = "Korean"
df.loc[df["Dili"] == "İbranice", "Dili"] = "Hebrew"
df.loc[df["Dili"] == "Macarca", "Dili"] = "Ungarisch"
df.loc[df["Dili"] == "Fince", "Dili"] = "Finnisch"
df.loc[df["Dili"] == "Azerice", "Dili"] = "Azerbaijani"
df.loc[df["Dili"] == "Uygur Türkçesi", "Dili"] = "Uighur"
df.loc[df["Dili"] == "Flemenkçe", "Dili"] = "Niederländisch"
df.loc[df["Dili"] == "Lehçe (dil)", "Dili"] = "Polnisch"
df.loc[df["Dili"] == "Azerbaycan Türkçesi", "Dili"] = "Azerbaijani"
df.loc[df["Dili"] == "Özbekçe", "Dili"] = "Uzbek"
df.loc[df["Dili"] == "İsveççe", "Dili"] = "Schwedisch"
df.loc[df["Dili"] == "Kırgızca", "Dili"] = "Kirghiz"
df.loc[df["Dili"] == "Kazakça", "Dili"] = "Kazakh"
df.loc[df["Dili"] == "Lazca", "Dili"] = "Turkish"
df.loc[df["Dili"] == "İrlandaca", "Dili"] = "Irish"
df.loc[df["Dili"] == "Ukrayna dili", "Dili"] = "Ukrainian"
df.loc[df["Dili"] == "Romence", "Dili"] = "Rumänisch"
df.loc[df["Dili"] == "Hırvatça", "Dili"] = "Croatian"
df.loc[df["Dili"] == "Gürcüce", "Dili"] = "Georgian"
df.loc[df["Dili"] == "Rumca", "Dili"] = "Griechisch"
df.loc[df["Dili"] == "Sırpça", "Dili"] = "Serbian"
df.loc[df["Dili"] == "Danca", "Dili"] = "Dänisch"

#Amazon Template Titles are created
df["feed_product_type"] = "abisbook"
df.rename({"Stok Kodu": "item_sku"}, axis=1, inplace=True)
df["external_product_id"] = df.loc[:,"item_sku"]
df["external_product_id_type"]="ISBN"
df["binding"] ="Flexibler Einband"
df.rename({"Id": "recommended_browse_nodes"}, axis=1, inplace=True)
df["recommended_browse_nodes"]=541686
df.rename({"Açıklama": "product_description"}, axis=1, inplace=True)
df.rename({"Yayınevi": "manufacturer"}, axis=1, inplace=True)
df.rename({"Basım Tarihi": "publication_date"}, axis=1, inplace=True)
df.rename({"Ürün Adı": "item_name"}, axis=1, inplace=True)
df.rename({"Dili": "language_value1"}, axis=1, inplace=True)
df.rename({"Yazar": "author"}, axis=1, inplace=True)
df["gdpr_risk"] = "Keine elektronischen Informationen gespeichert"
df["pages_unit_of_measure"] = "Seiten"
df["genre1"] = "Classical"
df["maximum_reading_interest_age"] = 99
df["minimum_reading_interest_age"] = 9
df.rename({"Sayfa Sayısı": "pages"}, axis=1, inplace=True)
df["minimum_reading_interest_age_unit_of_measure"] = "Tage"
df["maximum_reading_interest_age_unit_of_measure"] = "Monate"
df["country_of_origin"] = "Türkei"
df["eu_toys_safety_directive_warning1"] = "Kein Warnhinweis zutreffend"
df["eu_toys_safety_directive_age_warning"] = "Kein Warnhinweis zutreffend"
df.rename({"Resim": "main_image_url"}, axis=1, inplace=True)
df["quantity"] = "10"

#To overcome potential problems in big numbers, integers converted to strings
df["recommended_browse_nodes"] = df["recommended_browse_nodes"].astype(str)
df["item_sku"] = df["item_sku"].astype(str)
df["external_product_id"] = df["external_product_id"].astype(str)
df["standard_price"] = df["standard_price"].astype(int)
df["standard_price"] = df["standard_price"].astype(str)

#the other column titles in Amazon Template
df["language_value2"] = ""
df["language_value3"] = ""
df["language_value4"] = ""
df["language_value5"] = ""
df["author2"] = ""
df["author3"] = ""
df["author4"] = ""
df["author5"] = ""
df["genre2"] = ""
df["genre3"] = ""
df["genre4"] = ""
df["genre5"] = ""
df["eu_toys_safety_directive_warning2"] = ""
df["eu_toys_safety_directive_warning3"] = ""
df["eu_toys_safety_directive_warning4"] = ""
df["eu_toys_safety_directive_warning5"] = ""
df["eu_toys_safety_directive_warning6"] = ""
df["eu_toys_safety_directive_warning7"] = ""
df["eu_toys_safety_directive_warning8"] = ""

#Reordering the Titles in accordance with Amazon Template
df = df[['feed_product_type', 'item_sku', 'external_product_id', 
         'external_product_id_type', 'binding', 'product_description',
         'manufacturer', 'publication_date', 'item_name', 
         'language_value1', 'language_value2',
         'language_value3', 'language_value4', 'language_value5',
         'author', 'author2', 'author3', 'author4', 'author5',
         'recommended_browse_nodes', 'gdpr_risk',
         'pages_unit_of_measure', 'genre1', 'genre2', 
         'genre3', 'genre4', 'genre5',
         'maximum_reading_interest_age',
         'minimum_reading_interest_age', 'pages', 
         'minimum_reading_interest_age_unit_of_measure',
         'maximum_reading_interest_age_unit_of_measure',
         'country_of_origin',
         'eu_toys_safety_directive_warning1',
         'eu_toys_safety_directive_warning2',
       'eu_toys_safety_directive_warning3',
       'eu_toys_safety_directive_warning4',
       'eu_toys_safety_directive_warning5',
       'eu_toys_safety_directive_warning6',
       'eu_toys_safety_directive_warning7',
       'eu_toys_safety_directive_warning8',
         'eu_toys_safety_directive_age_warning',
         'main_image_url', 'quantity', 'standard_price']]

#Non admitted special characters are removed
df["product_description"] = df["product_description"].replace({r'&quot'}, {""}, regex=True)

#Excel does not allow more than 2000 characters in a cell. Thus those descriptions are truncated
df['product_description'] = df['product_description'].str[:1999]

df.to_excel(r'C:\\Users\\Casper\\Desktop\\amazon_df.xlsx', index=False)

#two titles will be added above above-mentioned titles on Excel to satisfy Amazon template criteria
